# %%
pwd
# Out:
# 'C:\\Users\\Zixiang'

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('soysnp50K_wm82.a2_41417.txt',sep='\t',index_col='rs#')

# %%
print(df.head())
# Out:
#                                 ltName alleles chrom    pos PI86046 PI90208  \
# rs#
# ss715578788  BARC_1.01_Gm_01_24939_A_G     A/G  GM01  24952       G       A
# ss715578818  BARC_1.01_Gm_01_25990_C_T     C/T  GM01  26003       T       C
# ss715578923  BARC_1.01_Gm_01_29658_A_G     A/G  GM01  29671       G       A
# ss715578960  BARC_1.01_Gm_01_30699_G_A     G/A  GM01  30712       G       G
# ss715579193  BARC_1.01_Gm_01_37005_C_T     C/T  GM01  37018       C       C
#
#             PI219698 PI253651A PI347550A PI398807  ... PI574480B PI578360  \
# rs#                                                ...
# ss715578788        -         A         A        A  ...         A        A
# ss715578818        -         C         C        C  ...         C        C
# ss715578923        H         A         A        A  ...         A        A
# ss715578960        G         G         G        G  ...         G        G
# ss715579193        H         C         C        C  ...         C        C
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42291 entries, ss715578788 to ss715633065
# Columns: 20091 entries, ltName to PI603516
# dtypes: int64(1), object(20090)
# memory usage: 6.3+ GB
# None

# %%
g_column_name=[cn for cn in df.columns]

# %%
g_column_name
# Out:
# ['ltName',
#  'alleles',
#  'chrom',
#  'pos',
#  'PI86046',
#  'PI90208',
#  'PI219698',
#  'PI253651A',
#  'PI347550A',
#  'PI398807',
#  'PI408055A',
#  'PI408069',
#  'PI408169A',
#  'PI408169B',
#  'PI416923',
#  'PI417472A',
#  'PI417508',
#  'PI417521',
#  'PI423734',
#  'PI423923',
#  'PI424145',
#  'PI424159A',
#  'PI424241',
#  'PI424485',
#  'PI424549B',
#  'PI437196',
#  'PI437199',
#  'PI437619',
#  'PI437633A',
#  'PI437649B',
#  'PI437749',
#  'PI437833',
#  'PI437841',
#  'PI438229',
#  'PI438249B',
#  'PI438250B',
#  'PI438251',
#  'PI438252A',
#  'PI438252C',
#  'PI438313',
#  'PI445825',
#  'PI458139',
#  'PI458181',
#  'PI506560',
#  'PI506574',
#  'PI506575A',
#  'PI506711B',
#  'PI506847',
#  'PI506992',
#  'PI507344',
#  'PI507368',
#  'PI507541',
#  'PI509111',
#  'PI548449',
#  'PI549076A',
#  'PI561348',
#  'PI567433A',
#  'PI567451',
#  'PI567453',
#  'PI567518',
#  'PI567603A',
#  'PI567679C',
#  'PI567767C',
#  'PI578386',
#  'PI578485A',
#  'PI587583B',
# ...

# %%
p_df = pd.read_csv('trait.txt',sep='\t')

# %%
print(p_df)
# Out:
#               id   oil  protein  yield
# 0       PI103414  21.6     37.7   2.28
# 1       PI132215  20.4     39.7   1.84
# 2       PI135589  15.5     39.1   1.91
# 3       PI135590  16.0     41.0   1.61
# 4       PI142491  19.8     39.9   1.82
# 5       PI153214  18.2     41.1   1.82
# 6       PI153229  19.5     38.3   1.74
# 7       PI153236  20.4     39.0   2.07
# 8       PI153247  20.0     39.5   1.95
# 9       PI153255  20.8     36.9   2.20
# 10      PI153264  19.9     37.5   2.37
# 11      PI153266  21.0     37.1   1.71
# 12      PI153276  21.1     37.3   1.82
# 13      PI153288  20.2     37.9   2.12
# 14      PI153310  21.8     38.1   2.19
# 15      PI153313  19.4     39.0   1.97
# 16      PI153315  19.4     38.9   2.00
# 17      PI153316  20.0     38.8   2.06
# 18      PI154195  21.0     37.5   2.04
# 19      PI171421  20.8     39.0   2.13
# 20      PI181533  19.4     39.0   1.96
# 21      PI181536  18.2     38.5   1.28
# 22      PI181537  19.2     39.3   1.10
# ...

# %%
p_column_name=[item for item in p_df.id]

# %%
print(p_column_name)
# Out:
# ['PI103414', 'PI132215', 'PI135589', 'PI135590', 'PI142491', 'PI153214', 'PI153229', 'PI153236', 'PI153247', 'PI153255', 'PI153264', 'PI153266', 'PI153276', 'PI153288', 'PI153310', 'PI153313', 'PI153315', 'PI153316', 'PI154195', 'PI171421', 'PI181533', 'PI181536', 'PI181537', 'PI181538', 'PI181570', 'PI184042', 'PI184045', 'PI184046', 'PI189863', 'PI189881', 'PI189890', 'PI189892', 'PI189896', 'PI189915', 'PI189917', 'PI189918', 'PI189919', 'PI189922', 'PI189924', 'PI189929', 'PI189931', 'PI189941', 'PI189945', 'PI189946', 'PI189947', 'PI189966', 'PI189967', 'PI189968', 'PI196150', 'PI196151', 'PI200508', 'PI200552', 'PI200592', 'PI200593', 'PI200594', 'PI227213', 'PI227325', 'PI227331', 'PI227558', 'PI227684', 'PI229328', 'PI232988', 'PI232989', 'PI232990', 'PI238922', 'PI248396', 'PI248398', 'PI248406', 'PI248407', 'PI248409', 'PI248410', 'PI250844', 'PI251585', 'PI251586', 'PI253650A', 'PI253650B', 'PI253652C', 'PI253652D', 'PI253653C', 'PI253658A', 'PI253658B', 'PI253658C', 'PI26
# ...

# %%
common_name=[value for value in g_column_name if value in p_column_name]

# %%
common_name
# Out:
# ['PI219698',
#  'PI253651A',
#  'PI347550A',
#  'PI408055A',
#  'PI408069',
#  'PI408169A',
#  'PI408169B',
#  'PI416923',
#  'PI417472A',
#  'PI417521',
#  'PI423734',
#  'PI423923',
#  'PI424145',
#  'PI424159A',
#  'PI424241',
#  'PI424485',
#  'PI424549B',
#  'PI437619',
#  'PI437749',
#  'PI437833',
#  'PI438252A',
#  'PI438252C',
#  'PI445825',
#  'PI458181',
#  'PI506560',
#  'PI506574',
#  'PI506575A',
#  'PI506711B',
#  'PI506847',
#  'PI507344',
#  'PI507368',
#  'PI548449',
#  'PI549076A',
#  'PI561348',
#  'PI567451',
#  'PI567453',
#  'PI567518',
#  'PI567603A',
#  'PI567679C',
#  'PI578386',
#  'PI578485A',
#  'PI587583B',
#  'PI594245B',
#  'PI594401B',
#  'PI594461A',
#  'PI605844E',
#  'PI612726',
#  'PI184047',
#  'PI189941',
#  'PI200462',
#  'PI241424',
#  'PI248404',
#  'PI317337',
#  'PI323560',
#  'PI361071B',
#  'PI361116',
#  'PI398202',
#  'PI398634',
#  'PI398772',
#  'PI398985',
#  'PI407795B',
#  'PI408095A',
#  'PI415072',
#  'PI417072',
#  'PI417115',
# ...

# %%
new_genotype=df[common_name]

# %%
print(new_genotype.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42291 entries, ss715578788 to ss715633065
# Columns: 8759 entries, PI219698 to PI587789
# dtypes: object(8759)
# memory usage: 2.8+ GB
# None

# %%
new_genotype.to_csv('new_genotyp.txt')

# %%
print(len(common_name))
# Out:
# 8759

# %%
new_pheno=p_df.loc[p_df['id'].isin(common_name)]

# %%
new_pheno.drop_duplicates(subset='id',keep='last')
# Out:
#               id   oil  protein  yield
# 0       PI103414  21.6     37.7   2.28
# 1       PI132215  20.4     39.7   1.84
# 5       PI153214  18.2     41.1   1.82
# 6       PI153229  19.5     38.3   1.74
# 7       PI153236  20.4     39.0   2.07
# 8       PI153247  20.0     39.5   1.95
# 12      PI153276  21.1     37.3   1.82
# 13      PI153288  20.2     37.9   2.12
# 14      PI153310  21.8     38.1   2.19
# 15      PI153313  19.4     39.0   1.97
# 16      PI153315  19.4     38.9   2.00
# 17      PI153316  20.0     38.8   2.06
# 18      PI154195  21.0     37.5   2.04
# 19      PI171421  20.8     39.0   2.13
# 20      PI181533  19.4     39.0   1.96
# 21      PI181536  18.2     38.5   1.28
# 22      PI181537  19.2     39.3   1.10
# 24      PI181570  15.1     41.4   1.29
# 25      PI184042  20.4     37.2   2.21
# 27      PI184046  20.0     39.7   1.86
# 28      PI189863  19.7     38.1   1.72
# 29      PI189881  19.4     37.4   2.04
# 30      PI189890  20.0     36.9   1.97
# ...

# %%
new_phenotype.to_csv('new_p.txt')
